# %%
#im.putpixel((10,20),250)
pix=im.load()
#pix.size()

# %%
im.size
# Out:
# (496, 512)

# %%
x=np.array([[0]*3]*5)
x[3][1]=1
x[2][2]=6
x
# Out:
# array([[0, 0, 0],
#        [0, 0, 0],
#        [0, 0, 6],
#        [0, 1, 0],
#        [0, 0, 0]])

# %%
from PIL import Image
import numpy as np
import math


def logistic_fn(x):
    y=np.array([[0]*x.shape[1]]*x.shape[0])
    for i in range(x.shape[0]):
        for j in range(x.shape[1]):
            if x[i][j]==0:
                y[i][j]=0
            else:
                y[i][j]=math.log10(x[i][j])
    return np.array(y)
    
def imgtonp(path):
    img=Image.open(path)
    pix=img.load()
    img_np=np.array([[0]*img.size[1]]*img.size[0],dtype=float)
    for i in range(img.size[0]):
        for j in range(img.size[1]):
            img_np[i][j]=pix[i,j]
    return img_np
def intensitynormalisation(img):
    #im.putpixel((10,20),250)
    mx=0
    mn=255
    for i in range(img.shape[0]):
        for j in range(img.shape[1]):
            mx=max(img[i][j],mx)
            mn=min(img[i][j],mn)
    normal_img=np.array([[0]*img.shape[1]]*img.shape[0],dtype=float)
    for i in range(img.shape[0]):
        for j in range(img.shape[1]):
            normal_img[i][j]=(img[i][j]-mn)/(mx-mn)
            #print(i,j,normal_img[i][j])
    return (normal_img,mx,mn)

def raleightransformpoint(x,sigma):
    return x*math.exp(-1*(x**(2))/(2*sigma**2))/(sigma**2)
def raleightransformimg(img,sigma):
    trans_img=np.array([[0]*img.shape[1]]*img.shape[0],dtype=float)
    for i in range(img.shape[0]):
        for j in range(img.shape[1]):
            trans_img[i][j]=raleightransformpoint(img[i][j],sigma)
    return trans_img

        
def parameters(a):
    mean=np.mean(a)
    (m,n)=a.shape
    sqr=0
    pow4=0
    for i in range(0,m):
        for j in range(0,n):
            sqr+=pow(a[i][j]-mean,2)
            pow4+=pow(a[i][j]-mean,4)
    stddev=pow(sqr/(m*n),0.5)
    k=(m*n*pow4)/pow(sqr,2)
    return(mean,stddev,k)
def neuralinputs(path,):
    im = Image.open(path)
    return parameters()
    
            
    #print(np.array(normal_img)[30][50],normal_img[30][50])

# %%
'RABBANI DATASET/AMD Part1/AMD (1).E2E/2- 25- 2017 9- 10- 42 PM/Image 9.TIFF'
# Out:
# 'RABBANI DATASET/AMD Part1/AMD (1).E2E/2- 25- 2017 9- 10- 42 PM/Image 9.TIFF'

# %%
pix[200,300]
# Out:
# 74

# %%
intensitynormalisation(im)[200][300]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-197-53e296be9a1e> in <module>()
# ----> 1 intensitynormalisation(im)[200][300]
#
# IndexError: tuple index out of range

# %%
a=[[] for _ in range(3)]
a[0].append(5)
a
# Out:
# [[5], [], []]

# %%
for x in np.linspace(0,1,11):
    print(x)
# Out:
# 0.0
# 0.1
# 0.2
# 0.30000000000000004
# 0.4
# 0.5
# 0.6000000000000001
# 0.7000000000000001
# 0.8
# 0.9
# 1.0

# %%
import os
def filldata(path):
    features=1
    y=[]
    #x=[[] for _ in range(features)]
    x=[[] for _ in range(len(os.listdir(path))*len(np.linspace(1,2,11)))]
    #x=[]
    print(os.listdir(path))
    cnt=0
    for i in os.listdir(path):
        print(path)
        path_img=path+'/'+i
       
        for sigma in np.linspace(1,2,11):
            #r=parameters(logistic_fn(raleightransformimg(intensitynormalisation(imgtonp(path_img))[0],sigma)))
            r=imgtonp(path_img).flatten()
            print(type(r),r)
            #print(r)
            #for index,i in enumerate(r):
                #x[index].append(i)
            for j in r:
                x[cnt].append(j)
        
            y.append(sigma)
            cnt=cnt+1
    return (x,y)

# %%
w=np.array([0])
w[0]=np.array([3,3])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-161-7138a0d35c42> in <module>()
#       1 w=np.array([0])
# ----> 2 w[0]=np.array([3,3])
#
# ValueError: setting an array element with a sequence.

# %%
np.transpose(np.array(x))
# Out:
# array([array([0., 0., 0., ..., 0., 0., 0.]),
#        array([0., 0., 0., ..., 0., 0., 0.]),
#        array([0., 0., 0., ..., 0., 0., 0.]),
#        array([0., 0., 0., ..., 0., 0., 0.]),
#        array([0., 0., 0., ..., 0., 0., 0.]),
#        array([0., 0., 0., ..., 0., 0., 0.]),
#        array([0., 0., 0., ..., 0., 0., 0.]),
#        array([0., 0., 0., ..., 0., 0., 0.]),
#        array([0., 0., 0., ..., 0., 0., 0.]),
#        array([0., 0., 0., ..., 0., 0., 0.]),
#        array([0., 0., 0., ..., 0., 0., 0.]),
#        array([0., 0., 0., ..., 0., 0., 0.]),
#        array([0., 0., 0., ..., 0., 0., 0.]),
#        array([0., 0., 0., ..., 0., 0., 0.]),
#        array([0., 0., 0., ..., 0., 0., 0.]),
#        array([0., 0., 0., ..., 0., 0., 0.]),
#        array([0., 0., 0., ..., 0., 0., 0.]),
#        array([0., 0., 0., ..., 0., 0., 0.]),
#        array([0., 0., 0., ..., 0., 0., 0.]),
#        array([0., 0., 0., ..., 0., 0., 0.]),
#        array([0., 0., 0., ..., 0., 0., 0.]),
# ...

# %%
np.transpose(np.array(x))
# Out:
# array([array([0., 0., 0., ..., 0., 0., 0.]),
#        array([0., 0., 0., ..., 0., 0., 0.]),
#        array([0., 0., 0., ..., 0., 0., 0.]),
#        array([0., 0., 0., ..., 0., 0., 0.]),
#        array([0., 0., 0., ..., 0., 0., 0.]),
#        array([0., 0., 0., ..., 0., 0., 0.]),
#        array([0., 0., 0., ..., 0., 0., 0.]),
#        array([0., 0., 0., ..., 0., 0., 0.]),
#        array([0., 0., 0., ..., 0., 0., 0.]),
#        array([0., 0., 0., ..., 0., 0., 0.]),
#        array([0., 0., 0., ..., 0., 0., 0.]),
#        array([0., 0., 0., ..., 0., 0., 0.]),
#        array([0., 0., 0., ..., 0., 0., 0.]),
#        array([0., 0., 0., ..., 0., 0., 0.]),
#        array([0., 0., 0., ..., 0., 0., 0.]),
#        array([0., 0., 0., ..., 0., 0., 0.]),
#        array([0., 0., 0., ..., 0., 0., 0.]),
#        array([0., 0., 0., ..., 0., 0., 0.]),
#        array([0., 0., 0., ..., 0., 0., 0.]),
#        array([0., 0., 0., ..., 0., 0., 0.]),
#        array([0., 0., 0., ..., 0., 0., 0.]),
# ...

# %%
from keras.models import Sequential
from keras.layers import Dense
import numpy as np
from keras import backend as K
import math
def radbas(n):
    return K.exp(-n**2)
def purelin(n):
    return n
model = Sequential()
model.add(Dense(12, input_dim=253952, activation=purelin))
model.add(Dense(15, activation=radbas))
#model.add(Dense(7, activation='tanh'))
model.add(Dense(1, activation=radbas))
# compile the keras model
model.compile(loss='mean_squared_error', optimizer='Adam', metrics=['accuracy'])
# fit the keras model on the dataset
model.fit(np.array(x), np.array(y), epochs=400, batch_size=8)
# evaluate the keras model
_, accuracy = model.evaluate(np.array(np.transpose(x)),np.array(y))
print('Accuracy: %.2f' % (accuracy*100))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-100-1e2aede2d182> in <module>()
#      16 model.compile(loss='mean_squared_error', optimizer='Adam', metrics=['accuracy'])
#      17 # fit the keras model on the dataset
# ---> 18 model.fit(np.array(x), np.array(y), epochs=400, batch_size=8)
#      19 # evaluate the keras model
#      20 _, accuracy = model.evaluate(np.array(np.transpose(x)),np.array(y))
#
# ~/anaconda3/lib/python3.6/site-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_freq, max_queue_size, workers, use_multiprocessing, **kwargs)
#    1087             sample_weight=sample_weight,
#    1088             class_weight=class_weight,
# -> 1089             batch_size=batch_size)
# ...

# %%
np.array(x)
# Out:
# array([array([0., 0., 0., ..., 0., 0., 0.]),
#        array([0., 0., 0., ..., 0., 0., 0.]),
#        array([0., 0., 0., ..., 0., 0., 0.]),
#        array([0., 0., 0., ..., 0., 0., 0.]),
#        array([0., 0., 0., ..., 0., 0., 0.]),
#        array([0., 0., 0., ..., 0., 0., 0.]),
#        array([0., 0., 0., ..., 0., 0., 0.]),
#        array([0., 0., 0., ..., 0., 0., 0.]),
#        array([0., 0., 0., ..., 0., 0., 0.]),
#        array([0., 0., 0., ..., 0., 0., 0.]),
#        array([0., 0., 0., ..., 0., 0., 0.]),
#        array([0., 0., 0., ..., 0., 0., 0.]),
#        array([0., 0., 0., ..., 0., 0., 0.]),
#        array([0., 0., 0., ..., 0., 0., 0.]),
#        array([0., 0., 0., ..., 0., 0., 0.]),
#        array([0., 0., 0., ..., 0., 0., 0.]),
#        array([0., 0., 0., ..., 0., 0., 0.]),
#        array([0., 0., 0., ..., 0., 0., 0.]),
#        array([0., 0., 0., ..., 0., 0., 0.]),
#        array([0., 0., 0., ..., 0., 0., 0.]),
#        array([0., 0., 0., ..., 0., 0., 0.]),
# ...

# %%
z=filldata('RABBANI DATASET/Normal Part1/Normal (1).E2E/2- 25- 2017 11- 08- 16 PM')
print(z)
# Out:
# ['Image 28.TIFF', 'Image 1.TIFF', 'Image 27.TIFF', 'Image 6.TIFF', 'Image 10.TIFF', 'Image 2.TIFF', 'Image 25.TIFF', 'Image 18.TIFF', 'Image 11.TIFF', 'Image 3.TIFF', 'Image 17.TIFF', 'Image 9.TIFF', 'Image 29.TIFF', 'Image 8.TIFF', 'Image 4.TIFF', 'Image 12.TIFF', 'Image 26.TIFF', 'Image 16.TIFF', 'Image 22.TIFF', 'Image 5.TIFF', 'Image 19.TIFF', 'Image 20.TIFF', 'Image 24.TIFF', 'Image 14.TIFF', 'Image 15.TIFF', 'Image 30.TIFF', 'Image 0.TIFF', 'Image 13.TIFF', 'Image 21.TIFF', 'Image 23.TIFF', 'Image 31.TIFF', 'Image 7.TIFF']
# RABBANI DATASET/Normal Part1/Normal (1).E2E/2- 25- 2017 11- 08- 16 PM
# <class 'numpy.ndarray'> [0. 0. 0. ... 0. 0. 0.]
# <class 'numpy.ndarray'> [0. 0. 0. ... 0. 0. 0.]
# <class 'numpy.ndarray'> [0. 0. 0. ... 0. 0. 0.]
# <class 'numpy.ndarray'> [0. 0. 0. ... 0. 0. 0.]
# <class 'numpy.ndarray'> [0. 0. 0. ... 0. 0. 0.]
# <class 'numpy.ndarray'> [0. 0. 0. ... 0. 0. 0.]
# <class 'numpy.ndarray'> [0. 0. 0. ... 0. 0. 0.]
# ...

# %%
x=np.array(z[0])
x.size
# Out:
# 352

# %%
import os
os.listdir('RABBANI DATASET/AMD Part1/AMD (1).E2E/2- 25- 2017 9- 10- 42 PM')
# Out:
# ['Image 1.TIFF',
#  'Image 6.TIFF',
#  'Image 10.TIFF',
#  'Image 2.TIFF',
#  'Image 25.TIFF',
#  'Image 18.TIFF',
#  'Image 11.TIFF',
#  'Image 3.TIFF',
#  'Image 17.TIFF',
#  'Image 9.TIFF',
#  'Image 8.TIFF',
#  'Image 4.TIFF',
#  'Image 12.TIFF',
#  'Image 16.TIFF',
#  'Image 22.TIFF',
#  'Image 5.TIFF',
#  'Image 19.TIFF',
#  'Image 20.TIFF',
#  'Image 24.TIFF',
#  'Image 14.TIFF',
#  'Image 15.TIFF',
#  'Image 0.TIFF',
#  'Image 13.TIFF',
#  'Image 21.TIFF',
#  'Image 23.TIFF',
#  'Image 7.TIFF']

# %%
parameters(raleightransformimg(intensitynormalisation(im)[0],3))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-178-e4e51934e02e> in <module>()
# ----> 1 parameters(raleightransformimg(intensitynormalisation(im)[0],3))
#
# NameError: name 'im' is not defined

# %%
path='RABBANI DATASET/AMD Part1/AMD (1).E2E/2- 25- 2017 9- 10- 42 PM/Image 11.TIFF'
img,mx,mn=intensitynormalisation(imgtonp(path))
print(mx,mn)
#for i in range(200):
trans=raleightransformimg(img,3)
trans_norm,mx,mn=intensitynormalisation(trans)

#trans=trans*(mx-mn)+mn
#Image.fromarray(np.uint8(trans_norm[0]*255),'L').show()
#Image.fromarray(np.uint8(img*(mx-mn)+mn),'L').show()
cnt=0
for i in range(img.shape[0]):
    for j in range(img.shape[1]):
        if img[i][j]!=trans_norm[i][j]:
            cnt=cnt+1
            #print(img[i][j],trans_norm[0][i][j])
# Out:
# 249.0 0.0

# %%
p[10][200]
# Out:
# 74.0

# %%
p=imgtonp(path)
img,mx,mn=intensitynormalisation(imgtonp(path))
for i in range(p.shape[0]):
    for j in range(p.shape[1]):
        if p[i][j]!=(img[i][j]*249):
            print(p[i][j],img[i][j]*249)
# Out:
# 4.0 3.9999999999999996
# 8.0 7.999999999999999
# 8.0 7.999999999999999
# 8.0 7.999999999999999
# 2.0 1.9999999999999998
# 8.0 7.999999999999999
# 4.0 3.9999999999999996
# 2.0 1.9999999999999998
# 8.0 7.999999999999999
# 4.0 3.9999999999999996
# 63.0 62.99999999999999
# 63.0 62.99999999999999
# 4.0 3.9999999999999996
# 63.0 62.99999999999999
# 126.0 125.99999999999999
# 8.0 7.999999999999999
# 4.0 3.9999999999999996
# 8.0 7.999999999999999
# 8.0 7.999999999999999
# 8.0 7.999999999999999
# 2.0 1.9999999999999998
# 8.0 7.999999999999999
# 8.0 7.999999999999999
# 2.0 1.9999999999999998
# 8.0 7.999999999999999
# 8.0 7.999999999999999
# 8.0 7.999999999999999
# 8.0 7.999999999999999
# 4.0 3.9999999999999996
# 2.0 1.9999999999999998
# 8.0 7.999999999999999
# 8.0 7.999999999999999
# 2.0 1.9999999999999998
# 32.0 31.999999999999996
# 126.0 125.99999999999999
# 4.0 3.9999999999999996
# 32.0 31.999999999999996
# 32.0 31.999999999999996
# 32.0 31.999999999999996
# 2.0 1.9999999999999998
# ...

# %%
path='RABBANI DATASET/AMD Part1/AMD (1).E2E/2- 25- 2017 9- 10- 42 PM/Image 11.TIFF'
Image.fromarray(intensitynormalisation(raleightransformimg(intensitynormalisation(imgtonp(path))[0],10))[0]*249).show()
#Image.fromarray(img*249).show()
Image.fromarray(intensitynormalisation(raleightransformimg(intensitynormalisation(imgtonp(path))[0],1))[0]*249).show()
Image.fromarray(imgtonp(path)).show()

# %%
q=imageto
q.flatten()
# Out:
# array([2, 3, 4, 3, 5, 7])

# %%
q=imgtonp(path).flatten()[20000:20010]
p=(intensitynormalisation(raleightransformimg(intensitynormalisation(imgtonp(path))[0],0.9))[0]*249).flatten()[20000:20010]
for i in q-p:
        print(i)
# Out:
# -30.630490916266382
# -9.130133139510274
# 0.0
# -30.630490916266382
# -35.07857799955016
# -9.130133139510274
# 0.0
# -4.9893685806900265
# -35.07857799955016
# -26.03627154598322

# %%
import matplotlib.pyplot as plt

q=imgtonp(path).flatten()[20000:20010]
x=[_+1 for _ in range(10)]
fig,ax=plt.subplots()
col=['#F3F466','#3324F6','#FFF400','#11F434','#000000']
for sigma in range(1,6):
    p=(intensitynormalisation(raleightransformimg(intensitynormalisation(imgtonp(path))[0],sigma))[0]*249).flatten()[20000:20010]
    ax.scatter(x,abs(q-p),color=col[sigma-1],label=sigma)
    for i in q-p:
        print(i)
ax.legend(title='Sigma')
plt.title('Intensity difference from original for 10 random points')
plt.xlabel('Point number')
plt.ylabel('Intensity difference')
plt.show()
# Out:
# -23.926065793088533
# -7.118245733169314
# 0.0
# -23.926065793088533
# -27.419931461337853
# -7.118245733169314
# 0.0
# -3.8894561212821266
# -27.419931461337853
# -20.325193767367246
# -4.934466417220854
# -1.4615926363162277
# 0.0
# -4.934466417220854
# -5.6643052609771445
# -1.4615926363162277
# 0.0
# -0.7983972763923628
# -5.6643052609771445
# -4.185968021429083
# -2.1189114086104937
# -0.6271444951742797
# 0.0
# -2.1189114086104937
# -2.433001722079446
# -0.6271444951742797
# 0.0
# -0.342561869791445
# -2.433001722079446
# -1.7970631760163585
# -1.17772513295143
# -0.34848535222152677
# 0.0
# -1.17772513295143
# -1.3524338476158704
# -0.34848535222152677
# 0.0
# -0.19034812092213027
# -1.3524338476158704
# -0.9987533041918581
# -0.7495971953903222
# -0.22177672752560795
# 0.0
# -0.7495971953903222
# -0.8608343485741514
# -0.22177672752560795
# 0.0
# -0.12113695672319036
# -0.8608343485741514
# -0.6356609783475164

# %%
x=np.array(z[0])
y=np.array(z[1])
y.shape
# Out:
# (352,)

# %%
trans_norm[0][200][300]
# Out:
# 0.3793311843905287

# %%
intensitynormalisation(imgtonp(path)

# %%
img
